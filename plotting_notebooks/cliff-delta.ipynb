# %%
from sys import path

path.append("../")

from src.utils.statistical_analysis import (
    load_and_prepare_data,
    compute_statistics,
    make_plot,
)

# %% [markdown]
# # MWC2022

# %%
path_to_data = "../data.nosync/mwc2022/results/cliff_delta_complete-freqfet-3.json"
values_w_intervals, feature_names = load_and_prepare_data(path_to_data)

# %%
compute_statistics(values_w_intervals=values_w_intervals, events=["Sleep", "Awake"])
# Out:
# Average cliff δ for Sleep: 0.03
# Average cliff δ for Awake: -0.00
# Percentage of intervals where Sleep has larger cliff δ values: 23.81%
# Percentage of intervals where Awake has larger cliff δ values: 23.81%
# Percentage of intervals where there is no difference: 52.38%
#                                             p-value  above_threshold  \
# Component  Feature
# mixed-EDA  min_feat                    1.657716e-31             True
#            max_feat                    5.609443e-21             True
#            mean_feat                   3.442951e-38             True
#            std_feat                    1.000000e+00            False
#            dynamic_range_feat          1.000000e+00            False
#            slope_feat                  1.000000e+00            False
#            absolute_slope_feat         1.000000e+00            False
#            first_derivetive_mean_feat  1.000000e+00            False
#            first_derivative_std_feat   8.961484e-01            False
#            number_of_peaks_feat        1.000000e+00            False
#            dc_term                     1.923134e-08             True
#            sum_of_all_coefficients     1.923134e-08             True
#            information_entropy         3.316906e-14             True
#            spectral_energy             8.716438e-12             True
# phasic-EDA min_feat                    5.077012e-19             True
#            max_feat                    1.119729e-24             True
#            mean_feat                   6.088121e-37             True
#            std_feat                    8.836026e-01            False
#            dynamic_range_feat          6.652340e-01            False
#            slope_feat                  1.000000e+00            False
#            absolute_slope_feat         1.000000e+00            False
#            first_derivetive_mean_feat  1.000000e+00            False
#            first_derivative_std_feat   3.505632e-01            False
#            number_of_peaks_feat        8.565852e-01            False
#            dc_term                     8.842592e-07             True
#            sum_of_all_coefficients     8.842592e-07             True
#            information_entropy         7.417415e-09             True
#            spectral_energy             9.821743e-12             True
# tonic-EDA  min_feat                    2.663596e-04             True
#            max_feat                    2.106474e-01            False
#            mean_feat                   2.508720e-03             True
#            std_feat                    6.187854e-02            False
#            dynamic_range_feat          2.796568e-01            False
#            slope_feat                  1.000000e+00            False
#            absolute_slope_feat         2.793522e-01            False
#            first_derivetive_mean_feat  1.000000e+00            False
#            first_derivative_std_feat   4.640751e-02             True
#            number_of_peaks_feat        6.746193e-01            False
#            dc_term                     2.747501e-02             True
#            sum_of_all_coefficients     2.747501e-02             True
#            information_entropy         4.181737e-11             True
#            spectral_energy             5.143732e-01            False
#
#                                        negative_bigger?
# Component  Feature
# mixed-EDA  min_feat                               False
#            max_feat                               False
#            mean_feat                              False
#            std_feat                               False
#            dynamic_range_feat                     False
#            slope_feat                             False
#            absolute_slope_feat                    False
#            first_derivetive_mean_feat             False
#            first_derivative_std_feat              False
#            number_of_peaks_feat                   False
#            dc_term                                 True
#            sum_of_all_coefficients                 True
#            information_entropy                     True
#            spectral_energy                         True
# phasic-EDA min_feat                               False
#            max_feat                               False
#            mean_feat                              False
#            std_feat                               False
#            dynamic_range_feat                     False
#            slope_feat                             False
#            absolute_slope_feat                    False
#            first_derivetive_mean_feat             False
#            first_derivative_std_feat              False
#            number_of_peaks_feat                    True
#            dc_term                                 True
#            sum_of_all_coefficients                 True
#            information_entropy                     True
#            spectral_energy                         True
# tonic-EDA  min_feat                               False
#            max_feat                               False
#            mean_feat                              False
#            std_feat                               False
#            dynamic_range_feat                     False
#            slope_feat                              True
#            absolute_slope_feat                    False
#            first_derivetive_mean_feat             False
#            first_derivative_std_feat              False
#            number_of_peaks_feat                   False
#            dc_term                                 True
#            sum_of_all_coefficients                 True
#            information_entropy                    False
#            spectral_energy                         True

# %%
make_plot(
    values_w_intervals,
    "../final_visualizations/cliff_delta_complete-mwc2022-3.pdf",
    feature_names,
    classes_list=["Sleep", "Awake"],
    measure_name="Cliff's Delta",
    plot_title="Cliff's delta between left and right hand features",
)
# Out:
# /Users/leonardoalchieri/Desktop/GIT/LateralizationPhysiologicalWearables/plotting_notebooks/../src/utils/statistical_analysis.py:222: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(

# %% [markdown]
# # USILaughs

# %%
path_to_data = "../data.nosync/usilaughs/results/cliff_delta_complete-freqfet-3.json"
values_w_intervals, feature_names = load_and_prepare_data(path_to_data)

# %%
compute_statistics(values_w_intervals=values_w_intervals, events=["Cognitive Load", "Relaxation"])
# Out:
# Average cliff δ for Cognitive Load: 0.02
# Average cliff δ for Relaxation: -0.01
# Percentage of intervals where Cognitive Load has larger cliff δ values: 2.38%
# Percentage of intervals where Relaxation has larger cliff δ values: 11.90%
# Percentage of intervals where there is no difference: 85.71%
#                                         p-value  above_threshold  \
# Component  Feature
# mixed-EDA  min_feat                    0.023652             True
#            max_feat                    0.109207            False
#            mean_feat                   0.041127             True
#            std_feat                    1.000000            False
#            dynamic_range_feat          1.000000            False
#            slope_feat                  1.000000            False
#            absolute_slope_feat         1.000000            False
#            first_derivetive_mean_feat  1.000000            False
#            first_derivative_std_feat   1.000000            False
#            number_of_peaks_feat        1.000000            False
#            dc_term                     1.000000            False
#            sum_of_all_coefficients     1.000000            False
#            information_entropy         1.000000            False
#            spectral_energy             1.000000            False
# phasic-EDA min_feat                    0.001131             True
#            max_feat                    0.004648             True
#            mean_feat                   0.002218             True
#            std_feat                    1.000000            False
#            dynamic_range_feat          1.000000            False
#            slope_feat                  1.000000            False
#            absolute_slope_feat         1.000000            False
#            first_derivetive_mean_feat  1.000000            False
#            first_derivative_std_feat   0.005633             True
#            number_of_peaks_feat        1.000000            False
#            dc_term                     1.000000            False
#            sum_of_all_coefficients     1.000000            False
#            information_entropy         1.000000            False
#            spectral_energy             1.000000            False
# tonic-EDA  min_feat                    0.356730            False
#            max_feat                    0.217119            False
#            mean_feat                   0.381534            False
#            std_feat                    0.936332            False
#            dynamic_range_feat          0.683954            False
#            slope_feat                  1.000000            False
#            absolute_slope_feat         1.000000            False
#            first_derivetive_mean_feat  1.000000            False
#            first_derivative_std_feat   1.000000            False
#            number_of_peaks_feat        1.000000            False
#            dc_term                     1.000000            False
#            sum_of_all_coefficients     1.000000            False
#            information_entropy         1.000000            False
#            spectral_energy             1.000000            False
#
#                                        negative_bigger?
# Component  Feature
# mixed-EDA  min_feat                                True
#            max_feat                                True
#            mean_feat                               True
#            std_feat                               False
#            dynamic_range_feat                     False
#            slope_feat                             False
#            absolute_slope_feat                    False
#            first_derivetive_mean_feat             False
#            first_derivative_std_feat              False
#            number_of_peaks_feat                    True
#            dc_term                                False
#            sum_of_all_coefficients                False
#            information_entropy                     True
#            spectral_energy                        False
# phasic-EDA min_feat                                True
#            max_feat                                True
#            mean_feat                               True
#            std_feat                               False
#            dynamic_range_feat                     False
#            slope_feat                             False
#            absolute_slope_feat                    False
#            first_derivetive_mean_feat             False
#            first_derivative_std_feat              False
#            number_of_peaks_feat                   False
#            dc_term                                False
#            sum_of_all_coefficients                False
#            information_entropy                     True
#            spectral_energy                        False
# tonic-EDA  min_feat                               False
#            max_feat                               False
#            mean_feat                              False
#            std_feat                               False
#            dynamic_range_feat                     False
#            slope_feat                              True
#            absolute_slope_feat                    False
#            first_derivetive_mean_feat             False
#            first_derivative_std_feat              False
#            number_of_peaks_feat                    True
#            dc_term                                False
#            sum_of_all_coefficients                False
#            information_entropy                     True
#            spectral_energy                        False

# %%
make_plot(
    values_w_intervals,
    "../final_visualizations/cliff_delta_complete-usilaughs-3.pdf",
    feature_names,
    classes_list=["Cognitive Load", "Relaxation"],
    measure_name="Cliff's Delta",
    plot_title="Cliff's delta between left and right hand features",
)
# Out:
# /Users/leonardoalchieri/Desktop/GIT/LateralizationPhysiologicalWearables/plotting_notebooks/../src/utils/statistical_analysis.py:222: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
